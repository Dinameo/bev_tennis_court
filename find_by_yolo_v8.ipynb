# %%
from ultralytics import YOLO

# %%
yolo_model_link = "./weights/yolo11n-seg.pt"
config_link = "./datasets/mydata.yaml"
epochs=100

# %%
model = YOLO(yolo_model_link)

results = model.train(data=config_link, epochs=epochs)
# Out:
# New https://pypi.org/project/ultralytics/8.3.59 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.58  Python-3.10.14 torch-2.5.1+cpu CPU (12th Gen Intel Core(TM) i5-1240P)
# ...

# %%
from ultralytics import YOLO
import matplotlib.pyplot as plt
import cv2
import numpy as np

link_model = './runs/segment/train/weights/best.pt'
link_img = './datasets/images/train/tennis_court_16.JPG'


model = YOLO(link_model)

img = cv2.imread(link_img)
results = model(link_img)

for r in results:
    im_array = r.plot()  
    plt.figure(figsize=(10, 10))
    
    plt.imshow(cv2.cvtColor(im_array, cv2.COLOR_BGR2RGB)) 
    plt.axis('off') 
    plt.show()
# Out:
# image 1/1 d:\Code\ai project\bev_tennis_court\datasets\images\train\tennis_court_16.JPG: 640x640 1 San_tennis, 153.4ms
# Speed: 4.1ms preprocess, 153.4ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)

# %%
model.export(format="onnx")
# Out:
# Ultralytics 8.3.58  Python-3.10.14 torch-2.5.1+cpu CPU (12th Gen Intel Core(TM) i5-1240P)
#
# PyTorch: starting from 'runs\segment\train\weights\best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) ((1, 37, 8400), (1, 32, 160, 160)) (5.7 MB)
#
# ONNX: starting export with onnx 1.17.0 opset 19...
# ONNX: slimming with onnxslim 0.1.47...
# ONNX: export success  1.5s, saved as 'runs\segment\train\weights\best.onnx' (11.1 MB)
#
# Export complete (1.7s)
# Results saved to D:\Code\ai project\bev_tennis_court\runs\segment\train\weights
# Predict:         yolo predict task=segment model=runs\segment\train\weights\best.onnx imgsz=640
# Validate:        yolo val task=segment model=runs\segment\train\weights\best.onnx imgsz=640 data=./datasets/mydata.yaml
# Visualize:       https://netron.app
# 'runs\\segment\\train\\weights\\best.onnx'
