# %%
from ultralytics import YOLO

# %%
yolo_model_link = "./datasets/yolo11n-seg.pt"
config_link = "./cfg/mydata.yaml"
epochs=100

# %%
model = YOLO(yolo_model_link)

results = model.train(data=config_link, epochs=epochs)

# %%
from ultralytics import YOLO
import matplotlib.pyplot as plt
import cv2
import numpy as np

link_model = './datasets/runs/segment/train2/weights/best.pt'
link_img = './datasets/images/train/tennis_court_15.JPG'


model = YOLO(link_model)

img = cv2.imread(link_img)
results = model(link_img)

for r in results:
    im_array = r.plot()  
    plt.figure(figsize=(10, 10))
    
    plt.imshow(cv2.cvtColor(im_array, cv2.COLOR_BGR2RGB)) 
    plt.axis('off') 
    plt.show()
# Out:
# image 1/1 d:\Code\ai project\bev_tennis_court\datasets\images\train\tennis_court_15.JPG: 640x640 2 San_tenniss, 142.9ms
# Speed: 5.0ms preprocess, 142.9ms inference, 3.3ms postprocess per image at shape (1, 3, 640, 640)

# %%
model.export(format="onnx")
# Out:
# Ultralytics 8.3.58  Python-3.10.14 torch-2.5.1+cpu CPU (12th Gen Intel Core(TM) i5-1240P)
#
# PyTorch: starting from 'D:\Code\ai project\BEV\Tennis\datasets\coco8\runs\segment\train2\weights\best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) ((1, 37, 8400), (1, 32, 160, 160)) (5.7 MB)
# requirements: Ultralytics requirement ['onnxslim'] not found, attempting AutoUpdate...
# ...
#
# requirements: AutoUpdate success  4.1s, installed 1 package: ['onnxslim']
# requirements:  Restart runtime or rerun command for updates to take effect
#
#
# ONNX: starting export with onnx 1.17.0 opset 19...
# ONNX: slimming with onnxslim 0.1.47...
# ONNX: export success  5.9s, saved as 'D:\Code\ai project\BEV\Tennis\datasets\coco8\runs\segment\train2\weights\best.onnx' (11.1 MB)
#
# Export complete (6.2s)
# Results saved to D:\Code\ai project\BEV\Tennis\datasets\coco8\runs\segment\train2\weights
# ...
